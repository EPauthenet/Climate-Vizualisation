# %%
#Plot of one contour of 15% - March 2024
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import glob
import seaborn as sns  # Optional for aesthetics
import datetime
import numpy as np

data_path  = '/Users/epauthen/Documents/Database/Antarctic_Sea_Ice/v3p0/'
fig_path   = '/Users/epauthen/Documents/Database/Antarctic_Sea_Ice/v3p0_fig15_light/'
shape_path = '/Users/epauthen/Documents/Database/Antarctic_Sea_Ice/v3p0_shape15/'

# %%
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, C15x: 980, C15y: 980)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-05-03T12:00:00
#   * C15x     (C15x) float64 -2.538e+03 -2.512e+03 ... -2.512e+03 -2.512e+03
#   * C15y     (C15y) float64 1.338e+03 1.312e+03 ... 1.388e+03 1.362e+03
# Data variables:
#     *empty*
# Attributes: (12/43)
#     title:                     Sea Ice Concentration Climate Data Record Vers...
#     summary:                   This climate data record of sea ice concentrat...
#     topiccategory:             Oceans ClimatologyMeteorologyAtmosphere
#     geospatial_lat_min:        -90.0
#     geospatial_lat_max:        -16.62393
#     geospatial_lon_min:        -180.0
#     ...                        ...
#     algorithm:                 SICCI3LF (19V, 37V, 37H)
#     references:                Product User Manual v3 (2022),Algorithm Theore...
#     contributor_name:          Thomas Lavergne,Atle Soerensen,Rasmus Tonboe,C...
#     contributor_role:          PrincipalInvestigator,author,author,author,aut...
#     source:                    FCDR of SMMR / SSMI / SSMIS Brightness Tempera...
#     product_status:            released

# %%
file_list = glob.glob(shape_path + '*.nc')
for n in np.arange(len(file_list)):
    ds = xr.open_dataset(file_list[n])

    fig, (ax1,ax2) = plt.subplots(1,2,figsize = (10,4),dpi = 50)
    ax1.plot(ds.C15x,ds.C15y,c = 'black')
    ax1.scatter(ds.C15x[0],ds.C15y[0],c = 'tab:red',s = 40)
    ax1.set_title(str(ds.time.data[0])[0:10])
    ax1.tick_params(axis='x', colors='tab:blue')
    ax1.tick_params(axis='y', colors='tab:orange')

    ax2.plot(ds.C15y, c='tab:orange')
    ax2.scatter(0,ds.C15x[0],c = 'tab:red',s = 40)
    ax2.set_title(str(ds.time.data[0])[0:10])
    ax2.tick_params(axis='y', colors='tab:orange')

    ax_right = ax2.twinx()  # instantiate a second axes that shares the same x-axis
    ax_right.plot(ds.C15x, c='tab:blue')
    ax_right.scatter(0,ds.C15y[0],c = 'tab:red',s = 40)
    ax_right.tick_params(axis='y', labelcolor='tab:blue')

    ny = 4200
    ax1.set_xlim([-ny,ny])
    ax1.set_ylim([-ny,ny])
    ax2.set_ylim([-ny,ny])
    ax_right.set_ylim([-ny,ny])

    ax1.grid(linestyle = 'dotted')
    ax2.grid(linestyle = 'dotted')
    plt.savefig(fig_path + 'Contour_' + str(ds.time.data[0])[0:10] + '.png')
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [70], line 30
#      28 ax1.grid(linestyle = 'dotted')
#      29 ax2.grid(linestyle = 'dotted')
# ---> 30 plt.savefig(fig_path + 'Contour_' + str(ds.time.data[0])[0:10] + '.png')
#      31 plt.close()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py:859, in savefig(*args, **kwargs)
#     856 @_copy_docstring_and_deprecators(Figure.savefig)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:2311, in Figure.savefig(self, fname, transparent, **kwargs)
#    2308         patch.set_facecolor('none')
#    2309         patch.set_edgecolor('none')
# -> 2311 self.canvas.print_figure(fname, **kwargs)
#    2313 if transparent:
#    2314     for ax, cc in zip(self.axes, original_axes_colors):
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py:2210, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2207     _bbox_inches_restore = None
#    2209 try:
# -> 2210     result = print_method(
#    2211         filename,
#    2212         dpi=dpi,
#    2213         facecolor=facecolor,
#    2214         edgecolor=edgecolor,
#    2215         orientation=orientation,
#    2216         bbox_inches_restore=_bbox_inches_restore,
#    2217         **kwargs)
#    2218 finally:
#    2219     if bbox_inches and restore_bbox:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py:1639, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1631     cbook.warn_deprecated(
#    1632         '3.3', name=name,
#    1633         message='%(name)s() got unexpected keyword argument "'
#    1634                 + arg + '" which is no longer supported as of '
#    1635                 '%(since)s and will become an error '
#    1636                 '%(removal)s')
#    1637     kwargs.pop(arg)
# -> 1639 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     460 @_check_savefig_extra_args
#     461 def print_png(self, filename_or_obj, *args,
#     462               metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     FigureCanvasAgg.draw(self)
#     510     mpl.image.imsave(
#     511         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:407, in FigureCanvasAgg.draw(self)
#     403 # Acquire a lock on the shared font cache.
#     404 with RendererAgg.lock, \
#     405      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406       else nullcontext()):
# --> 407     self.figure.draw(self.renderer)
#     408     # A GUI class may be need to update a window using this draw, so
#     409     # don't forget to call the superclass.
#     410     super().draw()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:1863, in Figure.draw(self, renderer)
#    1860             # ValueError can occur when resizing a window.
#    1862     self.patch.draw(renderer)
# -> 1863     mimage._draw_list_compositing_images(
#    1864         renderer, self, artists, self.suppressComposite)
#    1866     renderer.close_group('figure')
#    1867 finally:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py:411, in _delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     401     deprecation_addendum = (
#     402         f"If any parameter follows {name!r}, they should be passed as "
#     403         f"keyword, not positionally.")
#     404     warn_deprecated(
#     405         since,
#     406         name=repr(name),
#    (...)
#     409                  else deprecation_addendum,
#     410         **kwargs)
# --> 411 return func(*inner_args, **inner_kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:2747, in _AxesBase.draw(self, renderer, inframe)
#    2744         a.draw(renderer)
#    2745     renderer.stop_rasterizing()
# -> 2747 mimage._draw_list_compositing_images(renderer, self, artists)
#    2749 renderer.close_group('axes')
#    2750 self.stale = False
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:1164, in Axis.draw(self, renderer, *args, **kwargs)
#    1161     return
#    1162 renderer.open_group(__name__, gid=self.get_gid())
# -> 1164 ticks_to_draw = self._update_ticks()
#    1165 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1166                                                         renderer)
#    1168 for tick in ticks_to_draw:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:1023, in Axis._update_ticks(self)
#    1021 major_locs = self.get_majorticklocs()
#    1022 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1023 major_ticks = self.get_major_ticks(len(major_locs))
#    1024 self.major.formatter.set_locs(major_locs)
#    1025 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:1382, in Axis.get_major_ticks(self, numticks)
#    1378     numticks = len(self.get_majorticklocs())
#    1380 while len(self.majorTicks) < numticks:
#    1381     # Update the new tick label properties from the old.
# -> 1382     tick = self._get_tick(major=True)
#    1383     self.majorTicks.append(tick)
#    1384     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:2306, in YAxis._get_tick(self, major)
#    2304 else:
#    2305     tick_kw = self._minor_tick_kw
# -> 2306 return YTick(self.axes, 0, major=major, **tick_kw)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:490, in YTick.__init__(self, *args, **kwargs)
#     489 def __init__(self, *args, **kwargs):
# --> 490     super().__init__(*args, **kwargs)
#     491     # x in axes coords, y in data coords
#     492     self.tick1line.set(
#     493         xdata=[0], ydata=[0],
#     494         transform=self.axes.get_yaxis_transform(which="tick1"),
#     495         marker=self._tickmarkers[0],
#     496     )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py:411, in _delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     401     deprecation_addendum = (
#     402         f"If any parameter follows {name!r}, they should be passed as "
#     403         f"keyword, not positionally.")
#     404     warn_deprecated(
#     405         since,
#     406         name=repr(name),
#    (...)
#     409                  else deprecation_addendum,
#     410         **kwargs)
# --> 411 return func(*inner_args, **inner_kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:159, in Tick.__init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     149 self.tick1line = mlines.Line2D(
#     150     [], [],
#     151     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     152     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     153 )
#     154 self.tick2line = mlines.Line2D(
#     155     [], [],
#     156     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     157     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     158 )
# --> 159 self.gridline = mlines.Line2D(
#     160     [], [],
#     161     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     162     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     163     **grid_kw,
#     164 )
#     165 self.gridline.get_path()._interpolation_steps = \
#     166     GRIDLINE_INTERPOLATION_STEPS
#     167 self.label1 = mtext.Text(
#     168     np.nan, np.nan,
#     169     fontsize=labelsize, color=labelcolor, visible=label1On)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/lines.py:390, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     386 self.set_markeredgewidth(markeredgewidth)
#     388 # update kwargs before updating data to give the caller a
#     389 # chance to init axes (and hence unit support)
# --> 390 self.update(kwargs)
#     391 self.pickradius = pickradius
#     392 self.ind_offset = 0
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py:998, in Artist.update(self, props)
#     995             if not callable(func):
#     996                 raise AttributeError(f"{type(self).__name__!r} object "
#     997                                      f"has no property {k!r}")
# --> 998             ret.append(func(v))
#     999 if ret:
#    1000     self.pchanged()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py:929, in Artist.set_alpha(self, alpha)
#     921 def set_alpha(self, alpha):
#     922     """
#     923     Set the alpha value used for blending - not supported on all backends.
#     924
#    (...)
#     927     alpha : float or None
#     928     """
# --> 929     if alpha is not None and not isinstance(alpha, Number):
#     930         raise TypeError('alpha must be a float or None')
#     931     self._alpha = alpha
#
# File ~/opt/anaconda3/lib/python3.8/abc.py:98, in ABCMeta.__instancecheck__(cls, instance)
#      96 def __instancecheck__(cls, instance):
#      97     """Override for isinstance(instance, cls)."""
# ---> 98     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:
